# %% [markdown]
# # 03 - Modeling and evaluation
#
# Trains four classifiers on NSL-KDD (Logistic Regression, Random Forest, HistGradientBoosting, MLP) as a binary task (normal vs. attack), and also runs a 5-class version of the Random Forest over the DARPA families.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import json
import pandas as pd
from IPython.display import Image
from ids_pipeline import config
from ids_pipeline.train_models import train_all

# %% [markdown]
# ## Run training (skip if you already ran `python -m ids_pipeline.run_pipeline`)

# %%
results = train_all()
results

# %% [markdown]
# ## Saved metrics

# %%
pd.read_csv(config.REPORTS_DIR / 'binary_results.csv')

# %% [markdown]
# ## Confusion matrices and ROC curves

# %%
for name in ['logreg','random_forest','hist_gbdt','mlp']:
    display(Image(filename=str(config.FIGURES_DIR / f'cm_binary_{name}.png')))

# %%
Image(filename=str(config.FIGURES_DIR / 'roc_binary.png'))

# %%
Image(filename=str(config.FIGURES_DIR / 'feature_importance_rf.png'))

# %% [markdown]
# ## Multi-class report

# %%
rep = json.load(open(config.REPORTS_DIR / 'multiclass_rf_report.json'))
pd.DataFrame(rep).T

# %%
Image(filename=str(config.FIGURES_DIR / 'cm_multiclass_rf.png'))
