# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# CS 210 final project, NSL-KDD intrusion detection.
#
# This notebook pokes at the cleaned connection records in our SQLite database. Make sure you've run the pipeline at least once before this:
#
# ```bash
# python -m ids_pipeline.run_pipeline --eda-only
# ```

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from ids_pipeline.features import load_dataframe
from ids_pipeline.visualize import (
    plot_class_balance, plot_protocol_distribution,
    plot_top_services, plot_bytes_distribution,
    plot_correlation_heatmap,
)

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load the cleaned data from SQLite

# %%
df = load_dataframe()
print('Shape:', df.shape)
df.head()

# %%
df.groupby(['split', 'attack_family']).size().unstack(fill_value=0)

# %% [markdown]
# ## 2. Class imbalance
#
# DoS dominates. R2L and U2R are rare. This is a known issue with NSL-KDD and is why we use class-weighted classifiers later.

# %%
plot_class_balance(df);

# %% [markdown]
# ## 3. Protocol vs. attack family

# %%
plot_protocol_distribution(df);

# %% [markdown]
# ## 4. Top services targeted by attacks

# %%
plot_top_services(df);

# %% [markdown]
# ## 5. Byte counts by family

# %%
plot_bytes_distribution(df);

# %% [markdown]
# ## 6. Feature correlations

# %%
plot_correlation_heatmap(df);
